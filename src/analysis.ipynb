# %%
# Libraries
import numpy as np
import pandas as pd
import re

# %%
# Importing 
atta = pd.read_csv(r'../data/atta_mod.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# c:\Users\enamo\Documents\ironhack\projects\data-cleaning-pandas\src\analysis.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/enamo/Documents/ironhack/projects/data-cleaning-pandas/src/analysis.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> # Importing
# ----> <a href='vscode-notebook-cell:/c%3A/Users/enamo/Documents/ironhack/projects/data-cleaning-pandas/src/analysis.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> atta = pd.read_csv(r'../data/atta_mod.csv')
#
# ...

# %%
# Columns in the project
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\enamo\Documents\ironhack\projects\data-cleaning-pandas\src\analysis.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/enamo/Documents/ironhack/projects/data-cleaning-pandas/src/analysis.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> # Columns in the project
# ----> <a href='vscode-notebook-cell:/c%3A/Users/enamo/Documents/ironhack/projects/data-cleaning-pandas/src/analysis.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> df.columns
#
# NameError: name 'df' is not defined

# %%
unique_values = attacks['fatal_boolean'].unique()
print(unique_values)
# Out:
# [nan]

# %%
df.groupby("type").aggregate({"fatal_boolean":"max"})

# %%
attacks.dtypes
# Out:
# Unnamed: 0         int64
# Date              object
# year             float64
# type              object
# country           object
# activity          object
# sex              float64
# injury            object
# fatal_boolean    float64
# time              object
# dtype: object

# %%
attacks.sample()
# Out:
#       Unnamed: 0         Date  year        type country             activity  \
# 3503        3503  17-Oct-1967   NaN  Unprovoked     USA  Standing on sandbar
#
#       sex            injury  fatal_boolean       time
# 3503  NaN  Left foot bitten            NaN  Afternoon

# %%
attacks.dtypes
